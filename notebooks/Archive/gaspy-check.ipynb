# %%
import requests
import time

locations = list()

def write_list_to_file(filename, lst):
    with open(filename, 'w') as f:
        for item in lst:
            f.write(str(item) + '\n')

# %%
for i in range(1,3000):
    url:str = f"https://www.gassy.co.nz/api/marker/{i}"
    print(url)

    payload = {}
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)
    if response.status_code == 200:
        print(" - found")
        locations.append(i)
    time.sleep(1)
# Out:
# https://www.gassy.co.nz/api/marker/1
#  - found
# https://www.gassy.co.nz/api/marker/2
# https://www.gassy.co.nz/api/marker/3
#  - found
# https://www.gassy.co.nz/api/marker/4
#  - found
# https://www.gassy.co.nz/api/marker/5
#  - found
# https://www.gassy.co.nz/api/marker/6
#  - found
# https://www.gassy.co.nz/api/marker/7
#  - found
# https://www.gassy.co.nz/api/marker/8
#  - found
# https://www.gassy.co.nz/api/marker/9
#  - found
# https://www.gassy.co.nz/api/marker/10
#  - found
# https://www.gassy.co.nz/api/marker/11
#  - found
# https://www.gassy.co.nz/api/marker/12
#  - found
# https://www.gassy.co.nz/api/marker/13
#  - found
# https://www.gassy.co.nz/api/marker/14
# https://www.gassy.co.nz/api/marker/15
#  - found
# https://www.gassy.co.nz/api/marker/16
#  - found
# https://www.gassy.co.nz/api/marker/17
#  - found
# https://www.gassy.co.nz/api/marker/18
#  - found
# https://www.gassy.co.nz/api/marker/19
#  - found
# https://www.gassy.co.nz/api/marker/20
#  - found
# https://www.gassy.co.nz/api/marker/21
#  - found
# https://www.gassy.co.nz/api/marker/22
#  - found
# https://www.gassy.co.nz/api/marker/23
#  - found
# https://www.gassy.co.nz/api/marker/24
#  - found
# https://www.gassy.co.nz/api/marker/25
#  - found
# https://www.gassy.co.nz/api/marker/26
#  - found
# https://www.gassy.co.nz/api/marker/27
#  - found
# https://www.gassy.co.nz/api/marker/28
# https://www.gassy.co.nz/api/marker/29
#  - found
# https://www.gassy.co.nz/api/marker/30
#  - found
# https://www.gassy.co.nz/api/marker/31
#  - found
# https://www.gassy.co.nz/api/marker/32
# https://www.gassy.co.nz/api/marker/33
#  - found
# https://www.gassy.co.nz/api/marker/34
#  - found
# https://www.gassy.co.nz/api/marker/35
#  - found
# https://www.gassy.co.nz/api/marker/36
# https://www.gassy.co.nz/api/marker/37
# https://www.gassy.co.nz/api/marker/38
#  - found
# https://www.gassy.co.nz/api/marker/39
#  - found
# https://www.gassy.co.nz/api/marker/40
# https://www.gassy.co.nz/api/marker/41
#  - found
# https://www.gassy.co.nz/api/marker/42
#  - found
# https://www.gassy.co.nz/api/marker/43
#  - found
# https://www.gassy.co.nz/api/marker/44
#  - found
# https://www.gassy.co.nz/api/marker/45
#  - found
# https://www.gassy.co.nz/api/marker/46
#  - found
# https://www.gassy.co.nz/api/marker/47
#  - found
# https://www.gassy.co.nz/api/marker/48
#  - found
# https://www.gassy.co.nz/api/marker/49
#  - found
# https://www.gassy.co.nz/api/marker/50
# https://www.gassy.co.nz/api/marker/51
#  - found
# https://www.gassy.co.nz/api/marker/52
#  - found
# https://www.gassy.co.nz/api/marker/53
#  - found
# https://www.gassy.co.nz/api/marker/54
#  - found
# https://www.gassy.co.nz/api/marker/55
# https://www.gassy.co.nz/api/marker/56
# https://www.gassy.co.nz/api/marker/57
#  - found
# https://www.gassy.co.nz/api/marker/58
# https://www.gassy.co.nz/api/marker/59
#  - found
# https://www.gassy.co.nz/api/marker/60
#  - found
# https://www.gassy.co.nz/api/marker/61
#  - found
# https://www.gassy.co.nz/api/marker/62
#  - found
# https://www.gassy.co.nz/api/marker/63
#  - found
# https://www.gassy.co.nz/api/marker/64
#  - found
# https://www.gassy.co.nz/api/marker/65
#  - found
# https://www.gassy.co.nz/api/marker/66
#  - found
# https://www.gassy.co.nz/api/marker/67
#  - found
# https://www.gassy.co.nz/api/marker/68
# https://www.gassy.co.nz/api/marker/69
#  - found
# https://www.gassy.co.nz/api/marker/70
#  - found
# https://www.gassy.co.nz/api/marker/71
#  - found
# https://www.gassy.co.nz/api/marker/72
#  - found
# https://www.gassy.co.nz/api/marker/73
# https://www.gassy.co.nz/api/marker/74
#  - found
# https://www.gassy.co.nz/api/marker/75
#  - found
# https://www.gassy.co.nz/api/marker/76
#  - found
# https://www.gassy.co.nz/api/marker/77
# https://www.gassy.co.nz/api/marker/78
#  - found
# https://www.gassy.co.nz/api/marker/79
#  - found
# https://www.gassy.co.nz/api/marker/80
# https://www.gassy.co.nz/api/marker/81
#  - found
# https://www.gassy.co.nz/api/marker/82
#  - found
# https://www.gassy.co.nz/api/marker/83
#  - found
# https://www.gassy.co.nz/api/marker/84
#  - found
# https://www.gassy.co.nz/api/marker/85
#  - found
# https://www.gassy.co.nz/api/marker/86
#  - found
# https://www.gassy.co.nz/api/marker/87
#  - found
# https://www.gassy.co.nz/api/marker/88
#  - found
# https://www.gassy.co.nz/api/marker/89
# https://www.gassy.co.nz/api/marker/90
#  - found
# https://www.gassy.co.nz/api/marker/91
#  - found
# https://www.gassy.co.nz/api/marker/92
#  - found
# https://www.gassy.co.nz/api/marker/93
#  - found
# https://www.gassy.co.nz/api/marker/94
#  - found
# https://www.gassy.co.nz/api/marker/95
#  - found
# https://www.gassy.co.nz/api/marker/96
#  - found
# https://www.gassy.co.nz/api/marker/97
# https://www.gassy.co.nz/api/marker/98
#  - found
# https://www.gassy.co.nz/api/marker/99
#  - found
# https://www.gassy.co.nz/api/marker/100
#  - found
# https://www.gassy.co.nz/api/marker/101
#  - found
# https://www.gassy.co.nz/api/marker/102
#  - found
# https://www.gassy.co.nz/api/marker/103
#  - found
# https://www.gassy.co.nz/api/marker/104
#  - found
# https://www.gassy.co.nz/api/marker/105
# https://www.gassy.co.nz/api/marker/106
#  - found
# https://www.gassy.co.nz/api/marker/107
#  - found
# https://www.gassy.co.nz/api/marker/108
#  - found
# https://www.gassy.co.nz/api/marker/109
#  - found
# https://www.gassy.co.nz/api/marker/110
# https://www.gassy.co.nz/api/marker/111
#  - found
# https://www.gassy.co.nz/api/marker/112
#  - found
# https://www.gassy.co.nz/api/marker/113
#  - found
# https://www.gassy.co.nz/api/marker/114
#  - found
# https://www.gassy.co.nz/api/marker/115
#  - found
# https://www.gassy.co.nz/api/marker/116
#  - found
# https://www.gassy.co.nz/api/marker/117
#  - found
# https://www.gassy.co.nz/api/marker/118
#  - found
# https://www.gassy.co.nz/api/marker/119
#  - found
# https://www.gassy.co.nz/api/marker/120
#  - found
# https://www.gassy.co.nz/api/marker/121
#  - found
# https://www.gassy.co.nz/api/marker/122
#  - found
# https://www.gassy.co.nz/api/marker/123
#  - found
# https://www.gassy.co.nz/api/marker/124
#  - found
# https://www.gassy.co.nz/api/marker/125
#  - found
# https://www.gassy.co.nz/api/marker/126
#  - found
# https://www.gassy.co.nz/api/marker/127
#  - found
# https://www.gassy.co.nz/api/marker/128
#  - found
# https://www.gassy.co.nz/api/marker/129
#  - found
# https://www.gassy.co.nz/api/marker/130
#  - found
# https://www.gassy.co.nz/api/marker/131
#  - found
# https://www.gassy.co.nz/api/marker/132
#  - found
# https://www.gassy.co.nz/api/marker/133
#  - found
# https://www.gassy.co.nz/api/marker/134
#  - found
# https://www.gassy.co.nz/api/marker/135
# https://www.gassy.co.nz/api/marker/136
#  - found
# https://www.gassy.co.nz/api/marker/137
# https://www.gassy.co.nz/api/marker/138

# %%
write_list_to_file("gaspy_locations.txt", locations)
